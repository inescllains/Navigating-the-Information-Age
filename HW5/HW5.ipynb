# %%
# !pip install googletrans==4.0.0rc1
# !pip install news-please

# %%
from newsplease import NewsPlease

# %% [markdown]
# Get the data

# %%
# urls_portuguese = [
#   "https://www.dn.pt/sociedade/marcelo-nega-cunha-a-hospital-e-admite-ir-para-tribunal-17282257.html",
#   "https://www.dn.pt/sociedade/tres-pessoas-deram-a-costa-apos-naufragio-de-veleiro-em-santa-cruz-17276514.html",
#   "https://www.dn.pt/sociedade/as-politicas-continuam-economicistas-refletindo-se-na-falta-de-professores-17240048.html",
#   "https://www.dn.pt/politica/negocio-de-pcp-com-imobiliaria-pode-configurar-crime-de-financiamento-ilegal--17268010.html",
#   "https://www.dn.pt/politica/be-desafia-marcelo-a-defender-imediato-cessar-fogo-e-estar-ao-lado-de-guterres--17282133.html",
#   "https://www.dn.pt/politica/nao-deviam-ter-comecado-esquerda-critica-pr-sobre-palestina-17279329.html",
#   "https://www.dn.pt/politica/dirigentes-socialistas-criticam-marcelo-17278741.html",
#   "https://www.dn.pt/internacional/israel-lider-religioso-iraniano-deixa-ameaca-nas-redes-sociais-em-hebraico-17274454.html",
#   "https://www.dn.pt/internacional/lider-do-hezbollah-aponta-o-dedo-aos-eua-e-nao-exclui-hipotese-de-guerra-total-17279337.html",
#   "https://www.dn.pt/internacional/familias-israelitas-levam-queixa-de-crimes-de-guerra-ao-tpi-17276100.html"
# ]

# %%
urls = [
  "https://www.publico.es/es/politica/podemos-completa-su-desconexion-de-sumar-y-toma-posicion-de-cara-a-la-investidura-de-sanchez/",
  "https://www.publico.es/es/politica/javier-de-andres-el-nuevo-lider-del-pp-vasco/",
  "https://www.publico.es/es/politica/belarra-teniamos-que-frenar-la-operacion-para-sustituir-a-podemos-por-una-izquierda-servil-al-regimen/",
  "https://www.publico.es/es/politica/consignas-franquistas-y-gritos-de-sanchez-a-prision-frente-a-la-sede-del-psoe-en-madrid/",
  "https://www.publico.es/es/politica/podemos-e-iu-en-alerta-por-el-reparto-ministerial-entre-pedro-sanchez-y-yolanda-diaz/",
  "https://www.publico.es/es/politica/la-fecha-de-investidura-a-la-espera-de-puigdemont/",
  "https://www.publico.es/es/politica/la-figura-del-verificador-entre-el-psoe-y-erc-un-primer-paso-hacia-la-supervision-de-las-negociaciones-del-conflicto-catalan/",
  "https://www.publico.es/es/politica/podemos-abre-una-nueva-etapa-para-desligarse-politica-y-estrategicamente-de-sumar/",
  "https://www.publico.es/es/politica/un-juzgado-de-madrid-estudiara-el-13-de-noviembre-una-medida-cautelar-de-paralizar-la-tramitacion-de-la-amnistia/",
  "https://www.publico.es/es/politica/la-audiencia-nacional-abre-juicio-por-terrorismo-contra-doce-miembros-de-los-cdr/"
]

# %%
articles = []
for url in urls:
  article = NewsPlease.from_url(url)
  articles.append(article)

articles

# %%
for_translation = []

for article in articles:
  for_translation.append(article.maintext)

titles = []

for article in articles:
  titles.append(article.title)

# %%
for_translation
# Out:
# ['El partido refuerza su autonomía frente a Yolanda Díaz en vísperas de la votación de investidura y abre la puerta a replantearse sus alianzas con otras fuerzas de la izquierda, como los comuns.\nEl refuerzo político e identitario de Podemos al margen de Sumar y de la correlación actual de fuerzas en el espacio de la izquierda alternativa ya es un mandato militante de la organización. Este sábado el partido ha anunciado la aprobación del texto que sienta las bases de la hoja de ruta que los de Ione Belarra seguirán de ahora en adelante, a días de la eventual investidura que afrontará Pedro Sánchez.\nEl documento sienta las bases o líneas generales de una estrategia cuyo alcance se verá en los próximos meses, pero que deja abierta la puerta a un giro profundo en el escenario no sólo de la legislatura, sino de la izquierda.\nPara ejemplo, el de la doble militancia. El texto recoge la prohibición de la doble militancia en el seno de la organización, es decir, que un inscrito de Podemos
# ...

# %%
# !pip install -U easynmt
# !pip install news-please

# %%
from easynmt import EasyNMT
import pandas as pd
from torch import cuda

# %% [markdown]
# GPU accelaration

# %%
device = 'cuda' if cuda.is_available() else None
print(device)
# Out:
# cuda

# %% [markdown]
# Select model

# %%
model = EasyNMT('m2m_100_1.2B', device = device)
#model = EasyNMT('opus-mt', device = device)

# %%
translated_texts = []
for t in model.translate_stream(for_translation, target_lang = "en", show_progress_bar = True, batch_size=5):
    print(t)
    print("___________")
    translated_texts.append(t)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 7704.45it/s]
# The party reinforces its autonomy against Yolanda Díaz on the eve of the voting of investors and opens the door to rethinking its alliances with other left forces, such as the communes.
# The political and identity reinforcement of Podemos on the sidelines of Sumar and the current correlation of forces in the space of the alternative left is already a militant mandate of the organization. This Saturday the party announced the approval of the text that sets the bases of the route sheet that Ione Belarra will follow from now on, days of the eventual investorship that will face Pedro Sánchez.
# The document sets the bases or general lines of a strategy whose scope will be seen in the coming months, but which leaves the door open to a deep turn in the stage not only of the legislature, but of the left.
# ...

# %% [markdown]
# Save to df for the facebook_m2m translation

# %%
translated_df = pd.DataFrame(list(zip(titles, for_translation, translated_texts, urls)),
                             columns = ['title', 'original_text', 'facebook_m2m', 'url'])

# %%
translated_df
# Out:
#                                                title  \
# 0  Podemos completa su desconexión de Sumar y tom...
# 1      Javier de Andrés, el nuevo líder del PP vasco
# 2  Belarra, tras la aprobación de la nueva hoja d...
# 3  Consignas franquistas y gritos de “Sánchez a p...
# 4  Podemos e IU, en alerta por el reparto ministe...
# 5  La fecha de investidura, a la espera de Puigde...
# 6  La figura del verificador entre el PSOE y ERC,...
# 7  Podemos abre una nueva etapa para desligarse p...
# 8  Un juzgado de Madrid estudiará el 13 de noviem...
# 9  La Audiencia Nacional abre juicio por terroris...
#
#                                        original_text  \
# 0  El partido refuerza su autonomía frente a Yola...
# 1  Carlos Iturgaiz, que este sábado es sustituido...
# 2  Podemos ya tiene una nueva hoja de ruta para a...
# 3  Los manifestantes concentrados en Ferraz prote...
# 4  Ambas organizaciones consultarán a su militanc...
# 5  La decisión sobre la fecha de investidura sigu...
# ...

# %%
translated_df.to_csv("translated_facebook.csv")

# %% [markdown]
# Translate with google translate

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from newsplease import NewsPlease
import textwrap
from googletrans import Translator
import pandas as pd

# %%
translator = Translator()

# %%
urls = [
  "https://www.publico.es/es/politica/podemos-completa-su-desconexion-de-sumar-y-toma-posicion-de-cara-a-la-investidura-de-sanchez/",
  "https://www.publico.es/es/politica/javier-de-andres-el-nuevo-lider-del-pp-vasco/",
  "https://www.publico.es/es/politica/belarra-teniamos-que-frenar-la-operacion-para-sustituir-a-podemos-por-una-izquierda-servil-al-regimen/",
  "https://www.publico.es/es/politica/consignas-franquistas-y-gritos-de-sanchez-a-prision-frente-a-la-sede-del-psoe-en-madrid/",
  "https://www.publico.es/es/politica/podemos-e-iu-en-alerta-por-el-reparto-ministerial-entre-pedro-sanchez-y-yolanda-diaz/",
  "https://www.publico.es/es/politica/la-fecha-de-investidura-a-la-espera-de-puigdemont/",
  "https://www.publico.es/es/politica/la-figura-del-verificador-entre-el-psoe-y-erc-un-primer-paso-hacia-la-supervision-de-las-negociaciones-del-conflicto-catalan/",
  "https://www.publico.es/es/politica/podemos-abre-una-nueva-etapa-para-desligarse-politica-y-estrategicamente-de-sumar/",
  "https://www.publico.es/es/politica/un-juzgado-de-madrid-estudiara-el-13-de-noviembre-una-medida-cautelar-de-paralizar-la-tramitacion-de-la-amnistia/",
  "https://www.publico.es/es/politica/la-audiencia-nacional-abre-juicio-por-terrorismo-contra-doce-miembros-de-los-cdr/"
]

# %%
titles = []
texts = []
translated_texts = []
url_list = []

# %%
# Create empty lists to store data


# Loop through each URL in the list
for url in urls:
    # Retrieve article data from the URL
    article = NewsPlease.from_url(url)

    # Extract title and main text
    title = article.title
    print(title)
    text = article.maintext
    print(text)

    # Split the text into smaller chunks
    text_split = textwrap.wrap(text, 500)
    translated = []

    # Translate each chunk and store in 'translated'
    for t in text_split:
        translation = translator.translate(t, dest='en', src='es')
        translated.append(translation.text)
        print(translated)

    # Join the translated chunks into a single string
    translated_final = ' '.join(translated)

    # Append data to lists
    titles.append(title)
    texts.append(text)
    translated_texts.append(translated_final)
    url_list.append(url)
# Out:
# Podemos completa su desconexión de Sumar y toma posición de cara a la investidura de Sánchez
# El partido refuerza su autonomía frente a Yolanda Díaz en vísperas de la votación de investidura y abre la puerta a replantearse sus alianzas con otras fuerzas de la izquierda, como los comuns.
# El refuerzo político e identitario de Podemos al margen de Sumar y de la correlación actual de fuerzas en el espacio de la izquierda alternativa ya es un mandato militante de la organización. Este sábado el partido ha anunciado la aprobación del texto que sienta las bases de la hoja de ruta que los de Ione Belarra seguirán de ahora en adelante, a días de la eventual investidura que afrontará Pedro Sánchez.
# El documento sienta las bases o líneas generales de una estrategia cuyo alcance se verá en los próximos meses, pero que deja abierta la puerta a un giro profundo en el escenario no sólo de la legislatura, sino de la izquierda.
# ...

# %%
df_google = pd.DataFrame(list(zip(titles, texts, translated_texts, url_list)),
                  columns=['title', 'original_text', 'google_translate', 'url'])

# %%
df_google.to_csv("translated_google.csv")

# %% [markdown]
# Merge all three dataframes

# %%
df_google = pd.read_csv("translated_google.csv")

# %%
df_google
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Podemos completa su desconexión de Sumar y tom...
# 1           1      Javier de Andrés, el nuevo líder del PP vasco
# 2           2  Belarra, tras la aprobación de la nueva hoja d...
# 3           3  Consignas franquistas y gritos de “Sánchez a p...
# 4           4  Podemos e IU, en alerta por el reparto ministe...
# 5           5  La fecha de investidura, a la espera de Puigde...
# 6           6  La figura del verificador entre el PSOE y ERC,...
# 7           7  Podemos abre una nueva etapa para desligarse p...
# 8           8  Un juzgado de Madrid estudiará el 13 de noviem...
# 9           9  La Audiencia Nacional abre juicio por terroris...
#
#                                        original_text  \
# 0  El partido refuerza su autonomía frente a Yola...
# 1  Carlos Iturgaiz, que este sábado es sustituido...
# 2  Podemos ya tiene una nueva hoja de ruta para a...
# ...

# %%
df_opus = pd.read_csv("translated_opus.csv")

# %%
df_opus
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Podemos completa su desconexión de Sumar y tom...
# 1           1      Javier de Andrés, el nuevo líder del PP vasco
# 2           2  Belarra, tras la aprobación de la nueva hoja d...
# 3           3  Consignas franquistas y gritos de “Sánchez a p...
# 4           4  Podemos e IU, en alerta por el reparto ministe...
# 5           5  La fecha de investidura, a la espera de Puigde...
# 6           6  La figura del verificador entre el PSOE y ERC,...
# 7           7  Podemos abre una nueva etapa para desligarse p...
# 8           8  Un juzgado de Madrid estudiará el 13 de noviem...
# 9           9  La Audiencia Nacional abre juicio por terroris...
#
#                                        original_text  \
# 0  El partido refuerza su autonomía frente a Yola...
# 1  Carlos Iturgaiz, que este sábado es sustituido...
# 2  Podemos ya tiene una nueva hoja de ruta para a...
# ...

# %%
df_facebook = pd.read_csv("translated_facebook.csv")

# %%
df_facebook
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Podemos completa su desconexión de Sumar y tom...
# 1           1      Javier de Andrés, el nuevo líder del PP vasco
# 2           2  Belarra, tras la aprobación de la nueva hoja d...
# 3           3  Consignas franquistas y gritos de “Sánchez a p...
# 4           4  Podemos e IU, en alerta por el reparto ministe...
# 5           5  La fecha de investidura, a la espera de Puigde...
# 6           6  La figura del verificador entre el PSOE y ERC,...
# 7           7  Podemos abre una nueva etapa para desligarse p...
# 8           8  Un juzgado de Madrid estudiará el 13 de noviem...
# 9           9  La Audiencia Nacional abre juicio por terroris...
#
#                                        original_text  \
# 0  El partido refuerza su autonomía frente a Yola...
# 1  Carlos Iturgaiz, que este sábado es sustituido...
# 2  Podemos ya tiene una nueva hoja de ruta para a...
# ...

# %%
df_merged_1 = df_google.merge(df_opus, on=["title", "original_text", "url"], how="inner")

# %%
df_merged_1
# Out:
#    Unnamed: 0_x                                              title  \
# 0             0  Podemos completa su desconexión de Sumar y tom...
# 1             1      Javier de Andrés, el nuevo líder del PP vasco
# 2             2  Belarra, tras la aprobación de la nueva hoja d...
# 3             3  Consignas franquistas y gritos de “Sánchez a p...
# 4             4  Podemos e IU, en alerta por el reparto ministe...
# 5             5  La fecha de investidura, a la espera de Puigde...
# 6             6  La figura del verificador entre el PSOE y ERC,...
# 7             7  Podemos abre una nueva etapa para desligarse p...
# 8             8  Un juzgado de Madrid estudiará el 13 de noviem...
# 9             9  La Audiencia Nacional abre juicio por terroris...
#
#                                        original_text  \
# 0  El partido refuerza su autonomía frente a Yola...
# 1  Carlos Iturgaiz, que este sábado es sustituido...
# 2  Podemos ya tiene una nueva hoja de ruta para a...
# ...

# %%
df_merged_final = df_merged_1.merge(df_facebook, on=["title", "original_text", "url"], how="inner"d)

# %%
df_merged_final
# Out:
#    Unnamed: 0_x                                              title  \
# 0             0  Podemos completa su desconexión de Sumar y tom...
# 1             1      Javier de Andrés, el nuevo líder del PP vasco
# 2             2  Belarra, tras la aprobación de la nueva hoja d...
# 3             3  Consignas franquistas y gritos de “Sánchez a p...
# 4             4  Podemos e IU, en alerta por el reparto ministe...
# 5             5  La fecha de investidura, a la espera de Puigde...
# 6             6  La figura del verificador entre el PSOE y ERC,...
# 7             7  Podemos abre una nueva etapa para desligarse p...
# 8             8  Un juzgado de Madrid estudiará el 13 de noviem...
# 9             9  La Audiencia Nacional abre juicio por terroris...
#
#                                        original_text  \
# 0  El partido refuerza su autonomía frente a Yola...
# 1  Carlos Iturgaiz, que este sábado es sustituido...
# 2  Podemos ya tiene una nueva hoja de ruta para a...
# ...

# %%
df_merged_final.columns
# Out:
# Index(['Unnamed: 0_x', 'title', 'original_text', 'google_translate', 'url',
#        'Unnamed: 0_y', 'opus-mt', 'Unnamed: 0', 'facebook_m2m'],
#       dtype='object')

# %%
df_merged_final.drop(columns=['Unnamed: 0_x', 'Unnamed: 0_y', 'Unnamed: 0'], inplace=True)

# %%
df_merged_final.columns
# Out:
# Index(['title', 'original_text', 'google_translate', 'url', 'opus-mt',
#        'facebook_m2m'],
#       dtype='object')

# %%
df_final = df_merged_final[['title', 'original_text', 'google_translate', 'opus-mt', 'facebook_m2m', 'url']]

# %%
df_final
# Out:
#                                                title  \
# 0  Podemos completa su desconexión de Sumar y tom...
# 1      Javier de Andrés, el nuevo líder del PP vasco
# 2  Belarra, tras la aprobación de la nueva hoja d...
# 3  Consignas franquistas y gritos de “Sánchez a p...
# 4  Podemos e IU, en alerta por el reparto ministe...
# 5  La fecha de investidura, a la espera de Puigde...
# 6  La figura del verificador entre el PSOE y ERC,...
# 7  Podemos abre una nueva etapa para desligarse p...
# 8  Un juzgado de Madrid estudiará el 13 de noviem...
# 9  La Audiencia Nacional abre juicio por terroris...
#
#                                        original_text  \
# 0  El partido refuerza su autonomía frente a Yola...
# 1  Carlos Iturgaiz, que este sábado es sustituido...
# 2  Podemos ya tiene una nueva hoja de ruta para a...
# 3  Los manifestantes concentrados en Ferraz prote...
# 4  Ambas organizaciones consultarán a su militanc...
# 5  La decisión sobre la fecha de investidura sigu...
# ...

# %%
df_final.to_csv("final_dataset_lains.csv")
